# %%
import getpass
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("Enter LangChain API Key: ")
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter GOOGLE API Key: ")

# omarallam@std.mans.edu.eg
# LangChain_API: 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

# Gemini_API(omarallam@std.mans.edu.eg): AIzaSyDzyMWZB82YyWKzf21k6qdiAn4JG6DXL-Q
# Gemini_API(omar777kh777allam@gmail.com): AIzaSyC57_NvRsktnNgLvtyutDclVkCS2I4MKDI
# Gemini_API(colabthirdcolab@gmail.com): AIzaSyDof2hE1nOYkSx3vslyRl696NVoBeXCKH8

# Tavily_API: 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

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    web_path="https://www.linkedin.com/in/omarallam22/"
)
docs = loader.load()

# %%
# analyze the link content with LLM and sign in to LinkedIn with tool
# filter the content to remove the redundancy 
# Feed the document to build the RAG
# Out:
# Document(metadata={'source': 'https://www.linkedin.com/in/omarallam22/', 'title': 'Omar Allam - Samsung Innovation Campus | LinkedIn', 'description': 'I am currently an undergraduate electronics and communication engineering student atâ€¦ Â· Experience: Samsung Innovation Campus Â· Education: Mansoura University Â· Location: Al Gharbiyah Â· 500+ connections on LinkedIn. View Omar Allamâ€™s profile on LinkedIn, a professional community of 1 billion members.', 'language': 'en'}, page_content="\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOmar Allam - Samsung Innovation Campus | LinkedIn\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n      Skip to main content\n    \n\n\n\nLinkedIn\n\n\n\n\n\n\n\n\n\n\n        Articles\n      \n\n\n\n\n\n\n\n        People\n      \n\n\n\n\n\n\n\n        Learning\n      \n\n\n\n\n\n\n\n        Jobs\n      \n\n\n\n\n\n\n\n        Games\n      \n\n\n\n\n\n      Join now\n    \n\n          Sign in\n      \n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n \n\n\n
# ...

# %%
https://www.linkedin.com/login?session_redirect=https%3A%2F%2Feg%2Elinkedin%2Ecom%2Fin%2Fomarallam22&fromSignIn=true&trk=public_profile_nav-header-signin

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options

# Create Chrome options
options = Options()
options.add_argument('--headless')  # Run Chrome in headless mode

# Create WebDriver instance
driver = webdriver.Chrome(executable_path="F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe",options=options)

driver.get("https://www.geeksforgeeks.org/scrape-linkedin-using-selenium-and-beautiful-soup-in-python/")
src = driver.page_source
soup = BeautifulSoup(src, "html")
soup
# Out:
# <html lang="en-US" prefix="og: http://ogp.me/ns#"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="Data Structures, Algorithms, Python, Java, C, C++, JavaScript, Android Development, SQL, Data Science, Machine Learning, PHP, Web Development, System Design, Tutorial, Technical Blogs, Interview Experience, Interview Preparation, Programming, Competitive Programming, Jobs, Coding Contests, GATE CSE, HTML, CSS, React, NodeJS, Placement, Aptitude, Quiz, Computer Science, Programming Examples, GeeksforGeeks Courses, Puzzles, SSC, Banking, UPSC, Commerce, Finance, CBSE, School, k12, General Knowledge, News, Mathematics, Exams" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0" name="viewport"/>
# <link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time


driver1 = webdriver.Chrome("F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")
driver1.get("https://linkedin.com/uas/login")
time.sleep(5)

""" driver2 = webdriver.Chrome("F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")
driver2.get("https://linkedin.com/uas/login")
time.sleep(5)
 """

username = driver1.find_element(By.ID, "username")
username.send_keys("omarallam@std.mans.edu.eg")

password = driver1.find_element(By.ID, "password")
password.send_keys("awzu_900")

""" username = driver2.find_element(By.ID, "username")
username.send_keys("omarallam@std.mans.edu.eg")

password = driver2.find_element(By.ID, "password")
password.send_keys("awzu_900") """

driver1.find_element(By.XPATH, "//button[@type='submit']").click()

""" driver2.find_element(By.XPATH, "//button[@type='submit']").click() """

driver1.get("https://www.linkedin.com/in/omarallam22/")
""" driver2.get("https://www.linkedin.com/in/mostafa-edrees11/") """
src1 = driver1.page_source
soup1 = BeautifulSoup(src1, "html")

""" src2 = driver2.page_source
soup2 = BeautifulSoup(src2, "html") """
# Out:
# ' src2 = driver2.page_source\nsoup2 = BeautifulSoup(src2, "html") '

# %%
""" soup = BeautifulSoup(src, 'html.parser')
soup """;

# %%
from linkedin_scrapper import ScrapLinkedInProfile as s
from selenium import webdriver

test_driver = webdriver.Chrome("F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")
profile_link = "https://www.linkedin.com/in/omarallam22/"
profile_link = "https://www.linkedin.com/in/mostafa-edrees11/"
#profile_link = "https://www.linkedin.com/in/mahmoudhegab/"

#scrapper_object = s(test_driver, profile_link)
scrapper_object

# %%
profile_link = "https://www.linkedin.com/in/mahmoudhegab/"

test_driver.get(profile_link)

# wrapping the html content in a bs4 soup
test_driver.

# %%
profile_card_sections = soup.findAll("section",{"class":"pv-profile-card"})

section_soup = [] 
for section in profile_card_sections:
    section_name = section.find("div").get('id')  # find gives the first occurence
    print(section_name)
    if section_name == "featured":
        section_soup.append(section)
        break
    
test_project_section = section_soup[0]
#test_project_section
# Out:
# highlights
# about
# featured

# %%
from ask_login import AskLogIn
from linkedin_scrapper import ScrapLinkedInProfile

login_object = AskLogIn(chrome_driver_path="F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")

driver = login_object.get_driver()

    
profile_link = "https://www.linkedin.com/in/mostafa-edrees11/"

scrapper_object = ScrapLinkedInProfile(driver=driver, profile_link=profile_link)

profile_dictionary = scrapper_object.scrap_all_sections()
profile_dictionary
# Out:
# ✔✔✔LogIn Succeeded✔✔✔
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 32.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ...

# %%
profile_dictionary
# Out:
# {'name': <bound method ScrapPersonalInfo._getName of <scrap_personal_info.ScrapPersonalInfo object at 0x00000281EF5412A0>>,
#  'headline': <bound method ScrapPersonalInfo._getHeadline of <scrap_personal_info.ScrapPersonalInfo object at 0x00000281EF5412A0>>,
#  'about': "A highly motivated individual, studying Electronics & Communication Engineering.\nI'm looking for great opportunities where I can enhance my knowledge and skills, seeking an opportunity as an embedded software engineer.",
# ...

# %%
test_driver.get("https://www.linkedin.com/in/mahmoudhegab/details/certifications/")
src = test_driver.page_source
from bs4 import BeautifulSoup
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="theme theme--mercado app-loader--default artdeco windows" lang="en"><head>
# <script nonce="">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <meta content="script-src-attr 'none'; require-trusted-types-for 'script'; trusted-types 'allow-duplicates' default jSecure highcharts dompurify" data-disposition="enforce" data-report-to="https://www.linkedin.com/security/csp?a=voyager-web&amp;m=bpr" data-sanitizer="jSecure" http-equiv="Content-Security-Policy" name="trusted-types"/>
# <title>(1) Licenses &amp; certifications | Mahmoud Hegab | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
items = [item for item in soup.find("section",{"class":"artdeco-card"}).find("ul").children if item.name=='li']
print(len(items))
for i in items:
    x = i.find("div",{"class":"justify-space-between"}).find("span",{"class":"visually-hidden"}).get_text()
    print(x)
# Out:
# 9
# AWS Certified Machine Learning - Specialty
# NLP Specialization
# Fundamentals of Deep Learning
# Data Science Professional
# Deep Learning Specialization
# Employment Skills
# AI Analyst
# Machine Learning Specialization
# Entrepreneurship

# %%
test_project_section
# Out:
# <section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
# <!-- -->
# <div class="pv-profile-card__anchor" id="licenses_and_certifications">
# </div>
# <!-- -->
# <!-- -->
# <div class="hyOpABAHljMnsntDIlPYzMchlphgdibOzJjEWjjc">
# <div class="pvs-header__top-container--no-stack">
# <div class="pvs-header__left-container--stack">
# <div class="NnlXlxOVXJYNWtxOknkIugYbevCdGitwNKA">
# <h2 class="pvs-header__title text-heading-large">
# <span aria-hidden="true"><!-- -->Licenses &amp; certifications<!-- --></span><span class="visually-hidden"><!-- -->Licenses &amp; certifications<!-- --></span>
# </h2>
# <!-- --><!-- --> </div>
# <!-- --> </div>
# <div class="pvs-header__right-container">
# <div class="">
# <div>
# ...

# %%
items = [item for item in test_project_section.find("section",{"class":"artdeco-card"}).find("ul").children if item.name=='li']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 items = [item for item in test_project_section.find("section",{"class":"artdeco-card"}).find("ul").children if item.name=='li']
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
len(test_project_section.findAll("div",{"data-view-name":"profile-component-entity"}))
# Out:
# 8

# %%
experience_items = [i for i in test_project_section.find("ul").children if i.name == 'li']
experience_items[0].get_text().replace("\n"," ").strip()
children = []
parents = []
for result in experience_items[3].findAll("div",{"class":"mr1"}):
    span = result.find("span",{"class":"visually-hidden"})
    if span == None:
        continue
    elif span.find("span",{"class":"white-space-pre"}) ==None:
        parents.append(span.get_text())
    else:
        children.append(span.get_text())

print("parent is: ", parents)
print("children are: ", children)
# Out:
# parent is:  ['Learn In Depth', 'Embedded Software Engineer, 2nd Star ⭐⭐', 'Embedded Software Engineer, 1st Star ⭐']
# children are:  []

# %%
for child in test_project_section.find("ul").children:
    if child.name == 'li':
        project_name = (child.find("div",{"class":"mr1"})
                                    .find("span",{"class":"visually-hidden"})
                                    .get_text())
        print(project_name)
# Out:
# Medical Image Classification with Fine-tuned ViT
# German Language Named-Entity Recognition with fine-tuned XLMRoberta model

# %%
test_project_section

# %%
profile_card_sections = scrapper_object.soup.findAll("section",{"class":"pv-profile-card"})

section_soup = [] 
for section in profile_card_sections:
    section_name = section.find("div").get('id')  # find gives the first occurence
    print(section_name)
    if section_name == "projects":
        section_soup.append(section)
        break
    
test_project_section = section_soup[0]
# Out:
# highlights
# about
# featured
# content_collections
# experience
# education
# licenses_and_certifications
# projects

# %%
projects = scrapper_object.get_projects(test_project_section)
projects
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 projects = scrapper_object.get_projects(test_project_section)
#       2 projects
#
# File f:\reproducing_whisper\linkedin_scrapper.py:86, in ScrapLinkedInProfile.get_projects(self, section_soup)
#      82         temp_section_soup = BeautifulSoup(temp_section_src, "lxml")
#      84         self.driver.get(self.profile_link+"#arrow-left-medium") # to return to the main page after entering the show-more-projects arrow.
# ---> 86         return self._collect_projects(temp_section_soup)
#      87 else:
#      88     return self._collect_projects(section_soup)
#
# File f:\reproducing_whisper\linkedin_scrapper.py:60, in ScrapLinkedInProfile._collect_projects(self, section_soup)
#      57 for child in section_soup.find("ul").children:
#      58         if child.name == 'li':
# ...

# %%
profile_card_sections = soup1.findAll("section",{"class":"pv-profile-card"})

# person has those number of sections in its profile
print(len(profile_card_sections))

# after marking the section, find its first div_id to know the name of the section
section_soup = [] 
for section in profile_card_sections:
    section_name = section.find("div").get('id')  # find gives the first occurence
    print(section_name)
    if section_name == "projects":
        section_soup.append(section)
        break
    
section_soup[0]
# Out:
# 14
# highlights
# about
# featured
# content_collections
# experience
# education
# licenses_and_certifications
# projects
# skills
# languages
# interests
# browsemap_recommendation
# pymk_recommendation_from_school
# company_recommendation
# {'Traffic Light Control System': 'Designed Traffic Light Control System with dual modes (Normal and Pedestrian) for efficient traffic \nmanagement and pedestrian safety. Incorporated sequential LED transitions and pedestrian \nactivation through external button press for enhanced usability. Streamlined car traffic flow while \nprioritizing pedestrian crossings, improving overall road safety.', 'PING PONG GAME': "it's a ping pong game using EXTI & LCD Drivers in Atmega32"}

# %%
# Out:
# 3

# %%
profile_link = "https://www.linkedin.com/in/mostafa-edrees11/"

all_links = soup1.findAll("a")
for link in all_links:
    if "navigation-index" in link.find('id'):
        navigation_link = link.get('href')
        driver1.get(navigation_link)
        temp_src = driver1.page_source
        temp_soup = BeautifulSoup(temp_src, "html")
    
        driver1.get(profile_link+"#arrow-left-medium") # to return to the main page after entering the show-more-projects arrow.

        


Projects1 = (
    soup1.find("a",{"id":"navigation-index-see-all-projects"}).get('href')
    )

if Projects1 != None:
    driver1.get(Projects1)
    temp_src = driver1.page_source
    temp_soup = BeautifulSoup(temp_src, "html")

    driver1.get(profile_link+"#arrow-left-medium") # to return to the main page after entering the show-more-projects arrow.
# Out:
# 'https://www.linkedin.com/in/mostafa-edrees11/details/projects?profileUrn=urn%3Ali%3Afsd_profile%3AACoAADh5AZ8BNmfNYYh_zRFvUohZpQW7f-o_4Zs'

# %%
from bs4 import BeautifulSoup

html_content = """
<section>
    <div id="known_div_id">First div</div>
    <div>Second div</div>
    <div>Third div</div>
</section>
"""

soup = BeautifulSoup(html_content, 'html.parser')

first_div = soup.find('div', id='known_div_id')
section = first_div.parent
all_divs = section.find_all('div')
third_div = all_divs[2]

print(third_div.text)  # Output: Third div
# Out:
# <section>
# <div id="known_div_id">First div</div>
# <div>Second div</div>
# <div>Third div</div>
# </section>

# %%
Projects2 = (
    soup2.find("div",{"data-view-name":"profile-component-entity"})
    .find("div",{"class":"text-body-medium"})
    .get_text().strip()
    )
Projects2
# Out:
# 'Machine Learning enthusiast || Undergraduate  Electronics & Communications Engineering student'

# %%
About1 = (soup1.find("div",{"class":"pv3"})
         .find("span",{"class":"visually-hidden"})
         .get_text()
        )
About1
# Out:
# "A highly motivated individual, studying Electronics & Communication Engineering.\nI'm looking for great opportunities where I can enhance my knowledge and skills, seeking an opportunity as an embedded software engineer."

# %%
About2 = (soup2.find("div",{"class":"pv3"})
         .find("span",{"class":"visually-hidden"})
         .get_text()
        )
About2
# Out:
# 'I am currently an undergraduate electronics and communication engineering student at Mansoura University. My technical study besides the faculty concentrates on AI specifically Machine Learning. Non-technically, I am interested in Graphic design and athletics.'

# %%
from bs4 import BeautifulSoup
import bs4
import re

src2 = """
<head> it is good</head>
<!---->
multiple line comment
<!---->
<!---->
second
<!---->
"""

soup2 = BeautifulSoup(src2, 'html.parser')


# Find all comments
pattern = r"<!---->\s*(.*?)\s*<!---->"
matches = re.findall(pattern, src, re.DOTALL | re.MULTILINE)  

# Iterate through comments and extract content between specific comments
target_content = None
for comment in matches:
    print(comment.strip())
# Out:
# <div class="artdeco-toasts_toasts" role="alert">
#
#
# <span class="artdeco-button__text">
#     Skip to search
# </span></button>
#
#         <button id="ember10" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view">
# </div>
#
#     <button id="ember12" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view ml4" data-test-hotkey-modal-trigger="">
# <use href="#close-medium" width="24" height="24"></use>
# </svg>
#
#
# <span class="artdeco-button__text">
#     Close jump menu
# </span></button>
#       </div>
#     </div>
#
#
#     <header id="global-nav" class="global-nav global-alert-offset-top
#
#         global-nav--visible">
#       <div class="global-nav__content">
#
#     <a class="app-aware-link " href="https://www.linkedin.com/feed/?nis=true" data-test-app-aware-link="">
#
#     <div class="ivm-image-view-model    global-nav__branding-logo">
#
# ...

# %%
import re

def extract_text_between_delimiters(text):
    """Extracts text between '' and '' in a given text string."""
    span_pattern = r'<span(.*?)/span'
    pattern = r"<!---->\s*(.*?)\s*<!---->"
    
    span_matches = re.findall(span_pattern, text, re.DOTALL)
    
    for span_match in span_matches:
        matches = re.findall(pattern, span_match)
        for match in matches:
            print(match)



extract_text_between_delimiters(src)

# matches = [f"This Person Name is {soup.find('h1').text} and the following is information about him/her linked In profile \n\n"] + matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 17
#      12         for match in matches:
#      13             print(match)
# ---> 17 extract_text_between_delimiters(src)
#
# NameError: name 'src' is not defined

# %%
from IPython.display import display

# %%
text = experience_items[0].get_text().replace("\n"," ").strip()

# %%
import getpass
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("Enter LangChain API Key: ")
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter GOOGLE API Key: ")

# omarallam@std.mans.edu.eg
# LangChain_API: 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
# Gemini_API: AIzaSyDzyMWZB82YyWKzf21k6qdiAn4JG6DXL-Q
# Tavily_API: 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

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            You will be given a text scrapped from LinkedIn Profile page sepcially the experience section.
            the text is given to you in the 'text' variable.
            your task is to output a json with the following keys 'Company_name',
            'Job_title' (or 'Job_titles' if a person serves more than once in this company).
            values for 'Title' or 'Titles' include both the job title and details if exist about this title or titles.
            possible subkeys for details may be (Employment_type (vallues for this may be: part-time, full-time, internship), Location, Description or Skills), 
            Ignore any image files.
            Output the dictionary only with out any other text,
            """
        ),
        "human",
        "{text}",
    ]
)

chain = prompt | model

# %%
t = chain.invoke({'text':text}).content
t
# Out:
# "```json\n{'Company_name': 'CAT Reloaded', 'Job_titles': [{'Job_title': 'Embedded Systems Supervisor', 'details': {'Employment_type': 'Present', 'Start_date': 'Jan 2024'}}, {'Job_title': 'Embedded Systems Member', 'details': {'Employment_type': 'Full-time', 'Start_date': 'Nov 2022', 'End_date': 'Jul 2024', 'Location': 'El Mansoura, Ad Daqahliyah, Egypt', 'Skills': 'C (Programming Language), Data structure  and +2 skills'}}]}\n```"

# %%
import json
t1 = t.strip("```json\n").strip("\n```")
dict(eval(t1))
# Out:
# {'Company_name': 'CAT Reloaded',
#  'Job_titles': [{'Job_title': 'Embedded Systems Supervisor',
#    'details': {'Employment_type': 'Present', 'Start_date': 'Jan 2024'}},
#   {'Job_title': 'Embedded Systems Member',
#    'details': {'Employment_type': 'Full-time',
#     'Start_date': 'Nov 2022',
#     'End_date': 'Jul 2024',
#     'Location': 'El Mansoura, Ad Daqahliyah, Egypt',
#     'Skills': 'C (Programming Language), Data structure  and +2 skills'}}]}

# %%
f:\reproducing_whisper\linkedin_scrapper.py:23: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.

The code that caused this warning is on line 23 of the file f:\reproducing_whisper\linkedin_scrapper.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.

  self.soup = BeautifulSoup(self.src, "html")
