# %%
import getpass
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("Enter LangChain API Key: ")
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter GOOGLE API Key: ")

# omarallam@std.mans.edu.eg
# LangChain_API: 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

# Gemini_API(omarallam@std.mans.edu.eg): AIzaSyDzyMWZB82YyWKzf21k6qdiAn4JG6DXL-Q
# Gemini_API(omar777kh777allam@gmail.com): AIzaSyC57_NvRsktnNgLvtyutDclVkCS2I4MKDI
# Gemini_API(colabthirdcolab@gmail.com): AIzaSyDof2hE1nOYkSx3vslyRl696NVoBeXCKH8

# Tavily_API: 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

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro")
os.environ["GOOGLE_API_KEY"] = "AIzaSyDzyMWZB82YyWKzf21k6qdiAn4JG6DXL-Q"

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    web_path="https://www.linkedin.com/in/omarallam22/"
)
docs = loader.load()

# %%
# analyze the link content with LLM and sign in to LinkedIn with tool
# filter the content to remove the redundancy 
# Feed the document to build the RAG
# Out:
# Document(metadata={'source': 'https://www.linkedin.com/in/omarallam22/', 'title': 'Omar Allam - Samsung Innovation Campus | LinkedIn', 'description': 'I am currently an undergraduate electronics and communication engineering student atâ€¦ Â· Experience: Samsung Innovation Campus Â· Education: Mansoura University Â· Location: Al Gharbiyah Â· 500+ connections on LinkedIn. View Omar Allamâ€™s profile on LinkedIn, a professional community of 1 billion members.', 'language': 'en'}, page_content="\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOmar Allam - Samsung Innovation Campus | LinkedIn\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n      Skip to main content\n    \n\n\n\nLinkedIn\n\n\n\n\n\n\n\n\n\n\n        Articles\n      \n\n\n\n\n\n\n\n        People\n      \n\n\n\n\n\n\n\n        Learning\n      \n\n\n\n\n\n\n\n        Jobs\n      \n\n\n\n\n\n\n\n        Games\n      \n\n\n\n\n\n      Join now\n    \n\n          Sign in\n      \n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n \n\n\n
# ...

# %%
https://www.linkedin.com/login?session_redirect=https%3A%2F%2Feg%2Elinkedin%2Ecom%2Fin%2Fomarallam22&fromSignIn=true&trk=public_profile_nav-header-signin

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options

# Create Chrome options
options = Options()
options.add_argument('--headless')  # Run Chrome in headless mode

# Create WebDriver instance
driver = webdriver.Chrome(executable_path="F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe",options=options)

driver.get("https://www.geeksforgeeks.org/scrape-linkedin-using-selenium-and-beautiful-soup-in-python/")
src = driver.page_source
soup = BeautifulSoup(src, "html")
soup
# Out:
# <html lang="en-US" prefix="og: http://ogp.me/ns#"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="Data Structures, Algorithms, Python, Java, C, C++, JavaScript, Android Development, SQL, Data Science, Machine Learning, PHP, Web Development, System Design, Tutorial, Technical Blogs, Interview Experience, Interview Preparation, Programming, Competitive Programming, Jobs, Coding Contests, GATE CSE, HTML, CSS, React, NodeJS, Placement, Aptitude, Quiz, Computer Science, Programming Examples, GeeksforGeeks Courses, Puzzles, SSC, Banking, UPSC, Commerce, Finance, CBSE, School, k12, General Knowledge, News, Mathematics, Exams" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0" name="viewport"/>
# <link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time


driver1 = webdriver.Chrome("F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")
driver1.get("https://linkedin.com/uas/login")
time.sleep(5)

""" driver2 = webdriver.Chrome("F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")
driver2.get("https://linkedin.com/uas/login")
time.sleep(5)
 """

username = driver1.find_element(By.ID, "username")
username.send_keys("omarallam@std.mans.edu.eg")

password = driver1.find_element(By.ID, "password")
password.send_keys("awzu_900")

""" username = driver2.find_element(By.ID, "username")
username.send_keys("omarallam@std.mans.edu.eg")

password = driver2.find_element(By.ID, "password")
password.send_keys("awzu_900") """

driver1.find_element(By.XPATH, "//button[@type='submit']").click()

""" driver2.find_element(By.XPATH, "//button[@type='submit']").click() """

driver1.get("https://www.linkedin.com/in/omarallam22/")
""" driver2.get("https://www.linkedin.com/in/mostafa-edrees11/") """
src1 = driver1.page_source
soup1 = BeautifulSoup(src1, "html")

""" src2 = driver2.page_source
soup2 = BeautifulSoup(src2, "html") """
# Out:
# ' src2 = driver2.page_source\nsoup2 = BeautifulSoup(src2, "html") '

# %%
""" soup = BeautifulSoup(src, 'html.parser')
soup """;

# %%
from linkedin_scrapper import ScrapLinkedInProfile as s
from selenium import webdriver

test_driver = webdriver.Chrome("F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")
profile_link = "https://www.linkedin.com/in/omarallam22/"
profile_link = "https://www.linkedin.com/in/mostafa-edrees11/"
#profile_link = "https://www.linkedin.com/in/mahmoudhegab/"

#scrapper_object = s(test_driver, profile_link)
scrapper_object

# %%
profile_link = "https://www.linkedin.com/in/mahmoudhegab/"

test_driver.get(profile_link)

# wrapping the html content in a bs4 soup
test_driver.

# %%
profile_card_sections = soup.findAll("section",{"class":"pv-profile-card"})

section_soup = [] 
for section in profile_card_sections:
    section_name = section.find("div").get('id')  # find gives the first occurence
    print(section_name)
    if section_name == "featured":
        section_soup.append(section)
        break
    
test_project_section = section_soup[0]
#test_project_section
# Out:
# highlights
# about
# featured

# %%
from ask_login import AskLogIn
from scrappers.full_profile_scrapper import ScrapLinkedInProfile

login_object = AskLogIn(chrome_driver_path="F:\My installed programs\web_drivers\chromedriver-win64\chromedriver.exe")

driver = login_object.get_driver()

profile_link = "https://www.linkedin.com/in/mostafa-edrees11/"

scrapper_object = ScrapLinkedInProfile(driver=driver, profile_link=profile_link)

profile_dictionary = scrapper_object.scrap_all_sections()
print(profile_dictionary)
# Out:
# ✔✔✔LogIn Succeeded✔✔✔
# highlights
# about
# featured
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ...

# %%
profile_dictionary.keys()
# Out:
# dict_keys(['name', 'headline', 'about', 'featured', 'experience', 'education', 'licenses_and_certifications', 'projects', 'self.skills'])

# %%
dict = {'name': 'Mostafa Edrees', 'headline': 'Embedded Systems Enthusiastic | Undergraduate Electronics and Communication Engineer', 'about': "A highly motivated individual, studying Electronics & Communication Engineering.\nI'm looking for great opportunities where I can enhance my knowledge and skills, seeking an opportunity as an embedded software engineer.", 'featured': ['This project simulates a CAN bus communication between two ECUs to control a speedometer using the CANoe tool. One ECU simulates the accelerator pedal, sending its status to the other ECU, which controls the speedometer. The project involved database creation, CAPL scripting for ECU simulation, GUI development for data visualization, and provided hands-on experience with CAN bus principles and the CANoe tool. \n', "I'm thrilled to have achieved my 2nd star in the Mastering Embedded Systems Online Diploma program on Learn In Depth!  This achievement involved passing the First Term Exams with a score of 79/90 and completing two challenging projects. The program has been an enriching experience, covering topics like C programming, embedded C, data structures, and system architecture. I'm excited to continue my journey in the field of embedded systems. \n", 'I participated in IEEE\'s IoT Hackathon as part of Team "Average A," where we developed a Fire Control and Smart IoT system with a user-friendly app. Although we didn\'t place in the top three, we received positive feedback. I\'m grateful for my dedicated teammates Ahmed Ali, Mostafa Selim, and Menna Eid. It was an enjoyable experience, and we\'re eager to participate again. Thanks for all the support! \n', 'The author achieved a perfect score on their midterm exam for their Embedded Systems Online Diploma, earning their first star in the program. They are excited to continue the diploma and learn more about embedded systems. \n'], 'experience': [{'Company_name': 'CAT Reloaded', 'Job_titles': [{'Job_title': 'Embedded Systems Supervisor', 'details': {'Employment_type': 'Present', 'Start_date': 'Jan 2024'}}, {'Job_title': 'Embedded Systems Member', 'details': {'Employment_type': 'Full-time', 'Start_date': 'Nov 2022', 'End_date': 'Jul 2024', 'Location': 'El Mansoura, Ad Daqahliyah, Egypt', 'Skills': 'C (Programming Language), Data structure  and +2 skills'}}]}, {'Company_name': 'STARKS MU', 'Job_titles': [{'Job_title': 'Embedded Systems Supervisor'}, {'Job_title': 'Embedded Systems Supervisor'}]}, '{\n"Company_name": "STARKS MUSTARKS MU",\n"Job_title": {\n"title": "Embedded systems trainee",\n"Employment_type": null,\n"Location": "El Mansoura, Ad Daqahliyah, Egypt",\n"Description": null,\n"Skills": [\n"C (Programming Language)"\n]\n}\n}', {'Company_name': 'Learn In Depth', 'Job_titles': [{'Job_title': 'Embedded Software Engineer, 2nd Star ⭐⭐', 'Employment_type': 'Internship', 'Dates': 'Feb 2023 - Aug 2023 · 7 mos', 'Description': 'First Term:-  Unit 1: Diploma Prerequisites  Unit 2: C Programming  Unit 3: Embedded C  Unit 4: System Architect  Unit 5: First Term Projects\n                                  Data structure  and Embedded C                              First Term Cetification'}, {'Job_title': 'Embedded Software Engineer, 1st Star ⭐', 'Dates': 'Nov 2022 - Feb 2023 · 4 mos', 'Description': 'Mid-Term: Unit 1: Diploma Prerequisites Unit 2: ◼ Introduction to Embedded System\u200e. ◼ Version Control System (git). ◼ C Programming Language ▫ C Basics ▫ Conditions & Loops ▫ Arrays & String ▫ Functions\n                                  C (Programming Language)                              Mid-Term, First Star'}]}], 'education': [{'School': 'Mansoura University', 'Duration_of_study': 'Oct 2020 - 2025', 'Details_about_study': 'Student'}], 'licenses_and_certifications': {'Embedded Software Engineer, 2nd star ⭐⭐': 'Learn In Depth', 'Cisco Certified Network Associate Industrial (CCNA I)': 'National Telecommunication Institute (NTI)', 'Employability skills ': 'Aspire Consulting and Training', 'Linux': 'Udemy'}, 'projects': {'Traffic Light Control System': 'Designed Traffic Light Control System with dual modes (Normal and Pedestrian) for efficient traffic \nmanagement and pedestrian safety. Incorporated sequential LED transitions and pedestrian \nactivation through external button press for enhanced usability. Streamlined car traffic flow while \nprioritizing pedestrian crossings, improving overall road safety.', 'PING PONG GAME': "it's a ping pong game using EXTI & LCD Drivers in Atmega32", 'AVR Calculator': 'This AVR calculator project is designed for the AVR microcontroller and includes features such as basic arithmetic operations (+, -, *, /), handling operands with more than one digit, support for negative numbers, memory of the last value for use in new operations, and special handling for division, including integer and fractional parts display and detection of math errors (division by zero).', 'Fire Control & Smart IOT system': "It's a fire alarm system detection in realtime connected with friendly user app customized for customers. Today, we have a story about a land. That land embraced us for thousands of years and gave us life, and food. Source to survive… Being able to work, Create, Build, and evolve around. as when we are here the world one billion, this number we think of several stars in the sky but unfortunately, this number refers to how many animals vanished due to unexpected fires in Egypt, California last year. 32 species of them are in danger of extinction. fires are one of the worst disasters to hit the country. It destroys everything not only buildings but also humans undermines the national economy by billions of dollars and destroys the bio-systems. All these effects affect sustainable development and prevent us from achieving this goal as it destroys the 3 main pillars of sustainable development which are.\n\n1- Environmental pillar ( climate )\n\n2- Economical pillar ( Business and cooperates )\n\n3- social pillar. (people and lives)", 'Student Management System': 'My new pure C project ☺\n\n- Problem Statement✌🏻😍\nA simple software for student information management system which can perform the following operations:\n1. Store first name of the student.\n2. Store last name of the student.\n3. Store unique roll number for every student.\n4. Store GPA for every student.\n5. Store courses registered by the student.\n\n- Approach❤👌🏻\nThe idea is to form an individual functions for every operation. All the functions are unified to form software.\n1. Add student details from file.\n2. Add student details manually.\n3. Find the student by the given roll number.\n4. Find the student by the given first name.\n5. Find the student registered in a course.\n6. Count number of students.\n7. Delete a student by the given roll number.\n8. Update a student by the given roll number.\n9. Print all student’s data.\n10. Exit the program with saving data in file. To recover it later 😉\n\n- Idea🔥😎\nThe software will consist of 5 files main.c, Student_Sys.c, Student_Sys.h, students.txt and, update_students.txt.\nThe main.c will contain the interface and calling the function, Student_Sys.c will contain the global variables and the body of the functions, Student_Sys.h will contain the definitions and the prototypes, Students.txt will contain the data, update_students.txt will contain the whole data before exit.\n\n1. We will have array of struct of 50 elements which is the max number of students.\n2. Each struct contains the student details.\n3. We can save all data base in file before exit.', 'Pressure Control System': '- In this project, I was trying to do this project from scratch after learn in depth how to do every step in any project from Case study, Methodology, Requirement Diagram to System Design Simulation.\n\nCheck report : https://drive.google.com/file/d/1yUQSch0_M2eVL6hSwuNjlYqlxFy8_veA/view\n\n- In this project, You will see that I designed the system "UML" using TTool.\n- Also, You will see files which I wrote all from scratch.\n 1- linker_script.ld\n 2- Makefile\n 3- startup.c\n\nI was written this code by concept of state machine in 4 modules. Also, don\'t forget to take a brief look at Map File which generated by linker & object dump of project.elf file.', 'Student Record System': 'Student Record System This is a simple project stores and manipulates a list of students records. Student record contains his name, year, unique id, and password. The program has two modes: admin mode and user mode, and you have to choose which mode you need at the start of the program. If you choose admin mode, you’ll be asked for the password and you have these privileges: Add student record. Remove student record. Edit student record. View student record. View all records. Edit admin password. And if you choose user mode, you’ll be asked for the id and the password, and you have these privileges: View your record. Edit your password.\nI wrote this program to practice more and more in Software design and C programming language.', 'Library Management System': 'It is a final project in C programming with Starks MU team\nThis project is to build a Library Management System to manage how the admins of the library and users manage their accounts', 'Multiple-Disease-Prediction-System-using-Machine-Learning': "Multiple Disease Prediction System using Machine Learning in Python. We also be deploying this web app using Streamlit. This web app can predict the diseases such as Diabetes, heart disease, Hyper blood pressure, and Parkinson's using Machine Learning.\n\nUsing Python programming languages and Machine Learning.\nUsing libraries such as Sklearn, Numpy, Pandas, Pickle, Seaborn and Streamlit.\nUsing Algorithms such as SVM and Logistic regression.\nUsing IDE like Google colab and Anaconda(Spyder)."}, 'skills': ['ARM', 'AVR', 'Embedded Systems', 'Algorithm', 'Embedded C', 'Data structure ', 'Git', 'C (Programming Language)', 'Problem Solving', 'Linux', 'Microsoft Word', 'Teamwork', 'Microsoft Excel']}

dict['education']
# Out:
# [{'School': 'Mansoura University',
#   'Duration_of_study': 'Oct 2020 - 2025',
#   'Details_about_study': 'Student'}]

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyDzyMWZB82YyWKzf21k6qdiAn4JG6DXL-Q"
model = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Your task is to build a resume sections. You have an text passed to describing the person you and from this text do the following:
            first, from the information given to you build and summarize the content of each section for the section in the following list ["Name", "Headline", "Summary", "Experience","Education","Projects","skills"].
            second, take this content and wrap it in html code (ex: skills section could be in unordered list, summary is just a paragraph, headline is just a text not h2 tag ...etc). 
            your final output should be a dictionary with keys as section names and values are html code for each corresponding section.
            
            Take care: if the person's text isn't written in formal and grammatically-correct way, rewrite it. Also don't stick to the content length, if a certain section is so long shorten it after summarization to fit the resume.  
            """
        ),
        "human",
        "{text}",
    ]
)

chain = prompt | model
result = chain.invoke({"text":str(dict)})

# %%
res = eval(result.content.strip("```html\n").strip("\n```"))
res
# Out:
# {'Name': '<h1>Mostafa Edrees</h1>',
#  'Headline': '<h2>Embedded Systems Enthusiastic | Undergraduate Electronics and Communication Engineer</h2>',
#  'Summary': '<p>Highly motivated Electronics & Communication Engineering student seeking opportunities to enhance embedded software engineering skills and knowledge. </p>',
# ...

# %%
res

# %%
profile_link = "https://www.linkedin.com/in/mostafa-edrees11/"

# %%
with open("resume_builder/pre_template.html", "r", encoding='utf-8') as f:
    content = f.read()

filled_html = content.format(name=res['Name'],
                             headline=res['Headline'],
                             profile_link= profile_link,
                             summary=res['Summary'],
                             education= res['Education'],
                             experience= res['Experience'],
                             projects= res['Projects'],
                             skills= res['skills']
                             )

with open("resume_builder/template.html", "w", encoding='utf-8') as f:
    f.write(filled_html)

# %%
from htmldocx import HtmlToDocx

new_parser = HtmlToDocx()
new_parser.parse_html_file("resume_builder/template.html", "docx_filename")
